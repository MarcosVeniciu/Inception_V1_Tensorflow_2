# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcosVeniciu/Inception_V1/blob/main/Inception_V1_3_softmax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Artigo: https://ai.plainenglish.io/googlenet-inceptionv1-with-tensorflow-9e7f3a161e87
# Codigo de referencia: https://github.com/tensorflow/models/blob/master/research/slim/nets/inception_v1.py
# Outras referencias de codigo: https://paperswithcode.com/paper/going-deeper-with-convolutions

# %% [markdown]
# ![Captura de tela de 2023-05-12 09-52-54.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2023-05-12 09-53-45.png](data:image/png;base64,...)

# %%
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from tensorflow import keras
from keras import layers
import tensorflow as tf

print(tf.__version__) # 2.12.0 (12/5/2023)
# Out:
# 2.12.0

# %%
image_size = (224, 224)
input_shape = image_size + (1,)
batch_size = 128
num_classes = 10

# %% [markdown]
# # Dataset

# %%
def _normalize_img(img, label):
    img = tf.cast(img, tf.float32)
    img = tf.image.resize(img,image_size)
    return (img, label)

train_ds, test_dataset = tfds.load(name="mnist", split=['train', 'test'], as_supervised=True)
#train_ds, val_ds, test_dataset = tfds.load(name="mnist", split=['train[:80%]', 'train[:20%]', 'test'], as_supervised=True)

# Build your input pipelines
train_ds = train_ds.shuffle(1024).batch(batch_size)
val_ds = val_ds.shuffle(1024).batch(batch_size)

train_ds = train_ds.map(_normalize_img)
#val_ds = val_ds.map(_normalize_img)

test_dataset = test_dataset.batch(batch_size)
test_dataset = test_dataset.map(_normalize_img)

# %%
import numpy as np
import cv2
from keras.utils import np_utils
# Preparing the Dataset

num_classes = 10
img_rows,img_cols = 224, 224

# Load training and validation sets
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)

# Resize images to 244x244
X_train = np.array([cv2.resize(img, (img_rows,img_cols)) for img in X_train[:,:,:,:][:3000]])
X_test = np.array([cv2.resize(img, (img_rows,img_cols)) for img in X_test[:,:,:,:][:3000]])
y_train = y_train[:3000]
y_test = y_test[:3000]

# Transform targets to keras compatible format
y_train = np_utils.to_categorical(y_train, num_classes)
y_test = np_utils.to_categorical(y_test, num_classes)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Making all the values range between 0 and 1
X_train = X_train / 255.0
X_test = X_test / 255.0

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# ((3000, 224, 224), (3000, 10), (3000, 224, 224), (3000, 10))

# %% [markdown]
# # Modelo

# %%
# Ob1: No artigo na primeira camada conv é 1x1 e na segunda é 5x5, no codigo é 1x1, e depois 3x3. MANTIVE O DO ARTIGO
# Ob2: No codigo de referencia foi usado axis=3. Mantive o do código.
# Ob3: A saida da Conv é 4, 4, 128, então usie uma camada Flatten pra transformar isso em um vetor

# %% [markdown]
# ## Blocos

# %%
def inception_3a(previous_layer):
  branch_0 = layers.Conv2D(filters=64, kernel_size = [1,1], padding='same', activation='relu', name='Inception_3a_Conv_1x1')(previous_layer)
  
  branch_1 = layers.Conv2D(filters=96, kernel_size = [1,1], padding='same', activation='relu', name='Inception_3a_Conv_3x3_reduce')(previous_layer)
  branch_1 = layers.Conv2D(filters=128, kernel_size = [3,3], padding='same', activation='relu', name='Inception_3a_Conv_3x3')(branch_1)

  branch_2 = layers.Conv2D(filters=16, kernel_size = [1,1], padding='same', activation='relu', name='Inception_3a_Conv_5x5_reduce')(previous_layer)
  branch_2 = layers.Conv2D(filters=32, kernel_size = [5,5], padding='same', activation='relu', name='Inception_3a_Conv_5x5')(branch_2) # Ob1

  branch_3 = layers.MaxPool2D(pool_size = [3,3], strides=(1, 1), padding='same', name='Inception_3a_MaxPool_3x3')(previous_layer)
  branch_3 = layers.Conv2D(filters=32, kernel_size = [1,1], padding='same', activation='relu', name='Inception_3a_Conv_1x1_pool_porj')(branch_3)

  # Concat
  return tf.concat(values=[branch_0, branch_1, branch_2, branch_3], axis=3, name='concat_Inception_3a') # Ob2



def inception_3b(previous_layer):
  branch_0 = layers.Conv2D(filters=128, kernel_size = [1,1], padding='same', activation='relu', name='Inception_3b_Conv_1x1')(previous_layer)
  
  branch_1 = layers.Conv2D(filters=128, kernel_size = [1,1], padding='same', activation='relu', name='Inception_3b_Conv_3x3_reduce')(previous_layer)
  branch_1 = layers.Conv2D(filters=192, kernel_size = [3,3], padding='same', activation='relu', name='Inception_3b_Conv_3x3')(branch_1)

  branch_2 = layers.Conv2D(filters=32, kernel_size = [1,1], padding='same', activation='relu', name='Inception_3b_Conv_5x5_reduce')(previous_layer)
  branch_2 = layers.Conv2D(filters=96, kernel_size = [5,5], padding='same', activation='relu', name='Inception_3b_Conv_5x5')(branch_2) # Ob1

  branch_3 = layers.MaxPool2D(pool_size = [3,3], strides=(1, 1), padding='same', name='Inception_3b_MaxPool_3x3')(previous_layer)
  branch_3 = layers.Conv2D(filters=64, kernel_size = [1,1], padding='same', activation='relu', name='Inception_3b_Conv_1x1_pool_porj')(branch_3)

  # Concat
  return tf.concat( values=[branch_0, branch_1, branch_2, branch_3], axis=3, name='concat_Inception_3b') # Ob2

# %%
def inception_4a(previous_layer):
  branch_0 = layers.Conv2D(filters=192, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4a_Conv_1x1')(previous_layer)
  
  branch_1 = layers.Conv2D(filters=96, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4a_Conv_3x3_reduce')(previous_layer)
  branch_1 = layers.Conv2D(filters=208, kernel_size = [3,3], padding='same', activation='relu', name='Inception_4a_Conv_3x3')(branch_1)

  branch_2 = layers.Conv2D(filters=16, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4a_Conv_5x5_reduce')(previous_layer)
  branch_2 = layers.Conv2D(filters=48, kernel_size = [5,5], padding='same', activation='relu', name='Inception_4a_Conv_5x5')(branch_2) # Ob1

  branch_3 = layers.MaxPool2D(pool_size = [3,3], strides=(1, 1), padding='same', name='Inception_4a_MaxPool_3x3')(previous_layer)
  branch_3 = layers.Conv2D(filters=64, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4a_Conv_1x1_pool_porj')(branch_3)

  # Concat
  return tf.concat( values=[branch_0, branch_1, branch_2, branch_3], axis=3, name='concat_Inception_4a') # Ob2



def inception_4b(previous_layer):
  branch_0 = layers.Conv2D(filters=160, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4b_Conv_1x1')(previous_layer)
  
  branch_1 = layers.Conv2D(filters=112, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4b_Conv_3x3_reduce')(previous_layer)
  branch_1 = layers.Conv2D(filters=224, kernel_size = [3,3], padding='same', activation='relu', name='Inception_4b_Conv_3x3')(branch_1)

  branch_2 = layers.Conv2D(filters=24, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4b_Conv_5x5_reduce')(previous_layer)
  branch_2 = layers.Conv2D(filters=64, kernel_size = [5,5], padding='same', activation='relu', name='Inception_4b_Conv_5x5')(branch_2) # Ob1

  branch_3 = layers.MaxPool2D(pool_size = [3,3], strides=(1, 1), padding='same', name='Inception_4b_MaxPool_3x3')(previous_layer)
  branch_3 = layers.Conv2D(filters=64, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4b_Conv_1x1_pool_porj')(branch_3)

  # Concat
  return tf.concat( values=[branch_0, branch_1, branch_2, branch_3], axis=3, name='concat_Inception_4b') # Ob2



def inception_4c(previous_layer):
  branch_0 = layers.Conv2D(filters=128, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4c_Conv_1x1')(previous_layer)
  
  branch_1 = layers.Conv2D(filters=128, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4c_Conv_3x3_reduce')(previous_layer)
  branch_1 = layers.Conv2D(filters=256, kernel_size = [3,3], padding='same', activation='relu', name='Inception_4c_Conv_3x3')(branch_1)

  branch_2 = layers.Conv2D(filters=24, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4c_Conv_5x5_reduce')(previous_layer)
  branch_2 = layers.Conv2D(filters=64, kernel_size = [5,5], padding='same', activation='relu', name='Inception_4c_Conv_5x5')(branch_2) # Ob1

  branch_3 = layers.MaxPool2D(pool_size = [3,3], strides=(1, 1), padding='same', name='Inception_4c_MaxPool_3x3')(previous_layer)
  branch_3 = layers.Conv2D(filters=64, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4c_Conv_1x1_pool_porj')(branch_3)

  # Concat
  return tf.concat( values=[branch_0, branch_1, branch_2, branch_3], axis=3, name='concat_Inception_4c') # Ob2



def inception_4d(previous_layer):
  branch_0 = layers.Conv2D(filters=112, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4d_Conv_1x1')(previous_layer)
  
  branch_1 = layers.Conv2D(filters=144, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4d_Conv_3x3_reduce')(previous_layer)
  branch_1 = layers.Conv2D(filters=288, kernel_size = [3,3], padding='same', activation='relu', name='Inception_4d_Conv_3x3')(branch_1)

  branch_2 = layers.Conv2D(filters=32, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4d_Conv_5x5_reduce')(previous_layer)
  branch_2 = layers.Conv2D(filters=64, kernel_size = [5,5], padding='same', activation='relu', name='Inception_4d_Conv_5x5')(branch_2) # Ob1

  branch_3 = layers.MaxPool2D(pool_size = [3,3], strides=(1, 1), padding='same', name='Inception_4d_MaxPool_3x3')(previous_layer)
  branch_3 = layers.Conv2D(filters=64, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4d_Conv_1x1_pool_porj')(branch_3)

  # Concat
  return tf.concat( values=[branch_0, branch_1, branch_2, branch_3], axis=3, name='concat_Inception_4d') # Ob2

def inception_4e(previous_layer):
  branch_0 = layers.Conv2D(filters=256, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4e_Conv_1x1')(previous_layer)
  
  branch_1 = layers.Conv2D(filters=160, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4e_Conv_3x3_reduce')(previous_layer)
  branch_1 = layers.Conv2D(filters=320, kernel_size = [3,3], padding='same', activation='relu', name='Inception_4e_Conv_3x3')(branch_1)

  branch_2 = layers.Conv2D(filters=32, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4e_Conv_5x5_reduce')(previous_layer)
  branch_2 = layers.Conv2D(filters=128, kernel_size = [5,5], padding='same', activation='relu', name='Inception_4e_Conv_5x5')(branch_2) # Ob1

  branch_3 = layers.MaxPool2D(pool_size = [3,3], strides=(1, 1), padding='same', name='Inception_4e_MaxPool_3x3')(previous_layer)
  branch_3 = layers.Conv2D(filters=128, kernel_size = [1,1], padding='same', activation='relu', name='Inception_4e_Conv_1x1_pool_porj')(branch_3)

  # Concat
  return tf.concat( values=[branch_0, branch_1, branch_2, branch_3], axis=3, name='concat_Inception_4e') # Ob2

# %%
def inception_5a(previous_layer):
  branch_0 = layers.Conv2D(filters=256, kernel_size = [1,1], padding='same', activation='relu', name='Inception_5a_Conv_1x1')(previous_layer)
  
  branch_1 = layers.Conv2D(filters=160, kernel_size = [1,1], padding='same', activation='relu', name='Inception_5a_Conv_3x3_reduce')(previous_layer)
  branch_1 = layers.Conv2D(filters=320, kernel_size = [3,3], padding='same', activation='relu', name='Inception_5a_Conv_3x3')(branch_1)

  branch_2 = layers.Conv2D(filters=32, kernel_size = [1,1], padding='same', activation='relu', name='Inception_5a_Conv_5x5_reduce')(previous_layer)
  branch_2 = layers.Conv2D(filters=128, kernel_size = [5,5], padding='same', activation='relu', name='Inception_5a_Conv_5x5')(branch_2) # Ob1

  branch_3 = layers.MaxPool2D(pool_size = [3,3], strides=(1, 1), padding='same', name='Inception_5a_MaxPool_3x3')(previous_layer)
  branch_3 = layers.Conv2D(filters=128, kernel_size = [1,1], padding='same', activation='relu', name='Inception_5a_Conv_1x1_pool_porj')(branch_3)

  # Concat
  return tf.concat( values=[branch_0, branch_1, branch_2, branch_3], axis=3, name='concat_Inception_5a') # Ob2



def inception_5b(previous_layer):
  branch_0 = layers.Conv2D(filters=384, kernel_size = [1,1], padding='same', activation='relu', name='Inception_5b_Conv_1x1')(previous_layer)
  
  branch_1 = layers.Conv2D(filters=192, kernel_size = [1,1], padding='same', activation='relu', name='Inception_5b_Conv_3x3_reduce')(previous_layer)
  branch_1 = layers.Conv2D(filters=384, kernel_size = [3,3], padding='same', activation='relu', name='Inception_5b_Conv_3x3')(branch_1)

  branch_2 = layers.Conv2D(filters=48, kernel_size = [1,1], padding='same', activation='relu', name='Inception_5b_Conv_5x5_reduce')(previous_layer)
  branch_2 = layers.Conv2D(filters=128, kernel_size = [5,5], padding='same', activation='relu', name='Inception_5b_Conv_5x5')(branch_2) # Ob1

  branch_3 = layers.MaxPool2D(pool_size = [3,3], strides=(1, 1), padding='same', name='Inception_5b_MaxPool_3x3')(previous_layer)
  branch_3 = layers.Conv2D(filters=128, kernel_size = [1,1], padding='same', activation='relu', name='Inception_5b_Conv_1x1_pool_porj')(branch_3)

  # Concat
  return tf.concat( values=[branch_0, branch_1, branch_2, branch_3], axis=3, name='concat_Inception_5b') # Ob2

# %% [markdown]
# ## Rede

# %%
def inception_v1(input_shape, num_classes):
  if num_classes == 2:
    activation = "sigmoid"
    units = 1
  else:
    activation = "softmax"
    units = num_classes

  inputs = keras.Input(shape = input_shape)
  #scale_layer = tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255)
  #x = scale_layer(inputs)

  x = layers.Conv2D(filters=64, kernel_size = [7,7], strides=2, padding='same', activation='relu')(inputs)
  x = layers.MaxPool2D(pool_size = [3,3], strides=2, padding='same')(x)
  x = layers.Conv2D(filters=64, kernel_size = [1,1], strides=1, padding='same', activation='relu')(x)
  x = layers.Conv2D(filters=192, kernel_size = [3,3], strides=1, padding='same', activation='relu')(x)
  x = layers.MaxPool2D(pool_size = [3,3], strides=2, padding='same')(x)

  x = inception_3a(x)
  x = inception_3b(x)

  x = layers.MaxPool2D(pool_size = [3,3], strides=2, padding='same')(x)

  x = inception_4a(x)

  # Softmax_0
  outputs_0 = layers.AveragePooling2D(pool_size=(5, 5), strides=3)(x)
  outputs_0 = layers.Conv2D(filters=128, kernel_size = [1,1], strides=1, padding='same', activation='relu')(outputs_0)
  outputs_0 = keras.layers.Flatten()(outputs_0) #Obs3
  outputs_0 = keras.layers.Dense(1024, activation=activation)(outputs_0)
  outputs_0 = keras.layers.Dropout(rate = 0.7)(outputs_0)
  outputs_0 = keras.layers.Dense(units, activation=activation, name="softmax_0")(outputs_0)



  x = inception_4b(x)
  x = inception_4c(x)

  x = inception_4d(x)

  # Softmax_1
  outputs_1 = layers.AveragePooling2D(pool_size=(5, 5), strides=3)(x)
  outputs_1 = layers.Conv2D(filters=128, kernel_size = [1,1], strides=1, padding='same', activation='relu')(outputs_1)
  outputs_1 = keras.layers.Flatten()(outputs_1) #Obs3
  outputs_1 = keras.layers.Dense(1024, activation=activation)(outputs_1)
  outputs_1 = keras.layers.Dropout(rate = 0.7)(outputs_1)
  outputs_1 = keras.layers.Dense(units, activation=activation, name="softmax_1")(outputs_1)


  x = inception_4e(x)

  x = layers.MaxPool2D(pool_size = [3,3], strides=2, padding='same')(x)
  
  x = inception_5a(x)
  x = inception_5b(x)  

  # Softmax_2
  x = keras.layers.AveragePooling2D(pool_size=(7, 7), strides=1, name="Olaha_eu")(x)
  x = keras.layers.Flatten()(x) #Obs3
  x = keras.layers.Dropout(rate = 0.4)(x)
  outputs_2 = keras.layers.Dense(units, activation=activation, name="softmax_2")(x)

  return keras.Model(inputs, [outputs_2, outputs_1, outputs_0], name="Inception_V1")

# %%
modelo_view = inception_v1(input_shape, num_classes)

# %%
modelo_view.summary()
# Out:
# Model: "Inception_V1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 224, 224, 1  0           []
#                                 )]
#
#  conv2d_35 (Conv2D)             (None, 112, 112, 64  3200        ['input_8[0][0]']
#                                 )
#
#  max_pooling2d_28 (MaxPooling2D  (None, 56, 56, 64)  0           ['conv2d_35[0][0]']
#  )
#
#  conv2d_36 (Conv2D)             (None, 56, 56, 64)   4160        ['max_pooling2d_28[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 56, 56, 192)  110784      ['conv2d_36[0][0]']
#
#  max_pooling2d_29 (MaxPooling2D  (None, 28, 28, 192)  0          ['conv2d_37[0][0]']
#  )
#
#  Inception_3a_Conv_3x3_reduce (  (None, 28, 28, 96)  18528       ['max_pooling2d_29[0][0]']
#  Conv2D)
#
#  Inception_3a_Conv_5x5_reduce (  (None, 28, 28, 16)  3088        ['max_pooling2d_29[0][0]']
#  Conv2D)
#
#  Inception_3a_MaxPool_3x3 (MaxP  (None, 28, 28, 192)  0          ['max_pooling2d_29[0][0]']
#  ooling2D)
#
#  Inception_3a_Conv_1x1 (Conv2D)  (None, 28, 28, 64)  12352       ['max_pooling2d_29[0][0]']
#
#  Inception_3a_Conv_3x3 (Conv2D)  (None, 28, 28, 128)  110720     ['Inception_3a_Conv_3x3_reduce[0]
#                                                                  [0]']
#
#  Inception_3a_Conv_5x5 (Conv2D)  (None, 28, 28, 32)  12832       ['Inception_3a_Conv_5x5_reduce[0]
#                                                                  [0]']
#
#  Inception_3a_Conv_1x1_pool_por  (None, 28, 28, 32)  6176        ['Inception_3a_MaxPool_3x3[0][0]'
#  j (Conv2D)                                                      ]
#
#  tf.concat_63 (TFOpLambda)      (None, 28, 28, 256)  0           ['Inception_3a_Conv_1x1[0][0]',
#                                                                   'Inception_3a_Conv_3x3[0][0]',
#                                                                   'Inception_3a_Conv_5x5[0][0]',
#                                                                   'Inception_3a_Conv_1x1_pool_porj
#                                                                  [0][0]']
#
#  Inception_3b_Conv_3x3_reduce (  (None, 28, 28, 128)  32896      ['tf.concat_63[0][0]']
#  Conv2D)
#
#  Inception_3b_Conv_5x5_reduce (  (None, 28, 28, 32)  8224        ['tf.concat_63[0][0]']
#  Conv2D)
#
#  Inception_3b_MaxPool_3x3 (MaxP  (None, 28, 28, 256)  0          ['tf.concat_63[0][0]']
#  ooling2D)
#
#  Inception_3b_Conv_1x1 (Conv2D)  (None, 28, 28, 128)  32896      ['tf.concat_63[0][0]']
#
#  Inception_3b_Conv_3x3 (Conv2D)  (None, 28, 28, 192)  221376     ['Inception_3b_Conv_3x3_reduce[0]
#                                                                  [0]']
#
#  Inception_3b_Conv_5x5 (Conv2D)  (None, 28, 28, 96)  76896       ['Inception_3b_Conv_5x5_reduce[0]
#                                                                  [0]']
#
#  Inception_3b_Conv_1x1_pool_por  (None, 28, 28, 64)  16448       ['Inception_3b_MaxPool_3x3[0][0]'
#  j (Conv2D)                                                      ]
#
#  tf.concat_64 (TFOpLambda)      (None, 28, 28, 480)  0           ['Inception_3b_Conv_1x1[0][0]',
#                                                                   'Inception_3b_Conv_3x3[0][0]',
#                                                                   'Inception_3b_Conv_5x5[0][0]',
#                                                                   'Inception_3b_Conv_1x1_pool_porj
#                                                                  [0][0]']
#
#  max_pooling2d_30 (MaxPooling2D  (None, 14, 14, 480)  0          ['tf.concat_64[0][0]']
#  )
#
#  Inception_4a_Conv_3x3_reduce (  (None, 14, 14, 96)  46176       ['max_pooling2d_30[0][0]']
#  Conv2D)
#
#  Inception_4a_Conv_5x5_reduce (  (None, 14, 14, 16)  7696        ['max_pooling2d_30[0][0]']
#  Conv2D)
#
#  Inception_4a_MaxPool_3x3 (MaxP  (None, 14, 14, 480)  0          ['max_pooling2d_30[0][0]']
#  ooling2D)
#
#  Inception_4a_Conv_1x1 (Conv2D)  (None, 14, 14, 192)  92352      ['max_pooling2d_30[0][0]']
#
#  Inception_4a_Conv_3x3 (Conv2D)  (None, 14, 14, 208)  179920     ['Inception_4a_Conv_3x3_reduce[0]
#                                                                  [0]']
#
#  Inception_4a_Conv_5x5 (Conv2D)  (None, 14, 14, 48)  19248       ['Inception_4a_Conv_5x5_reduce[0]
#                                                                  [0]']
#
#  Inception_4a_Conv_1x1_pool_por  (None, 14, 14, 64)  30784       ['Inception_4a_MaxPool_3x3[0][0]'
#  j (Conv2D)                                                      ]
#
#  tf.concat_65 (TFOpLambda)      (None, 14, 14, 512)  0           ['Inception_4a_Conv_1x1[0][0]',
#                                                                   'Inception_4a_Conv_3x3[0][0]',
#                                                                   'Inception_4a_Conv_5x5[0][0]',
#                                                                   'Inception_4a_Conv_1x1_pool_porj
#                                                                  [0][0]']
#
#  Inception_4b_Conv_3x3_reduce (  (None, 14, 14, 112)  57456      ['tf.concat_65[0][0]']
#  Conv2D)
#
#  Inception_4b_Conv_5x5_reduce (  (None, 14, 14, 24)  12312       ['tf.concat_65[0][0]']
#  Conv2D)
#
#  Inception_4b_MaxPool_3x3 (MaxP  (None, 14, 14, 512)  0          ['tf.concat_65[0][0]']
#  ooling2D)
#
#  Inception_4b_Conv_1x1 (Conv2D)  (None, 14, 14, 160)  82080      ['tf.concat_65[0][0]']
#
#  Inception_4b_Conv_3x3 (Conv2D)  (None, 14, 14, 224)  226016     ['Inception_4b_Conv_3x3_reduce[0]
#                                                                  [0]']
#
#  Inception_4b_Conv_5x5 (Conv2D)  (None, 14, 14, 64)  38464       ['Inception_4b_Conv_5x5_reduce[0]
#                                                                  [0]']
#
#  Inception_4b_Conv_1x1_pool_por  (None, 14, 14, 64)  32832       ['Inception_4b_MaxPool_3x3[0][0]'
#  j (Conv2D)                                                      ]
#
#  tf.concat_66 (TFOpLambda)      (None, 14, 14, 512)  0           ['Inception_4b_Conv_1x1[0][0]',
#                                                                   'Inception_4b_Conv_3x3[0][0]',
#                                                                   'Inception_4b_Conv_5x5[0][0]',
#                                                                   'Inception_4b_Conv_1x1_pool_porj
#                                                                  [0][0]']
#
#  Inception_4c_Conv_3x3_reduce (  (None, 14, 14, 128)  65664      ['tf.concat_66[0][0]']
#  Conv2D)
#
#  Inception_4c_Conv_5x5_reduce (  (None, 14, 14, 24)  12312       ['tf.concat_66[0][0]']
#  Conv2D)
#
#  Inception_4c_MaxPool_3x3 (MaxP  (None, 14, 14, 512)  0          ['tf.concat_66[0][0]']
#  ooling2D)
#
#  Inception_4c_Conv_1x1 (Conv2D)  (None, 14, 14, 128)  65664      ['tf.concat_66[0][0]']
#
#  Inception_4c_Conv_3x3 (Conv2D)  (None, 14, 14, 256)  295168     ['Inception_4c_Conv_3x3_reduce[0]
#                                                                  [0]']
#
#  Inception_4c_Conv_5x5 (Conv2D)  (None, 14, 14, 64)  38464       ['Inception_4c_Conv_5x5_reduce[0]
#                                                                  [0]']
#
#  Inception_4c_Conv_1x1_pool_por  (None, 14, 14, 64)  32832       ['Inception_4c_MaxPool_3x3[0][0]'
#  j (Conv2D)                                                      ]
#
#  tf.concat_67 (TFOpLambda)      (None, 14, 14, 512)  0           ['Inception_4c_Conv_1x1[0][0]',
#                                                                   'Inception_4c_Conv_3x3[0][0]',
#                                                                   'Inception_4c_Conv_5x5[0][0]',
#                                                                   'Inception_4c_Conv_1x1_pool_porj
#                                                                  [0][0]']
#
#  Inception_4d_Conv_3x3_reduce (  (None, 14, 14, 144)  73872      ['tf.concat_67[0][0]']
#  Conv2D)
#
#  Inception_4d_Conv_5x5_reduce (  (None, 14, 14, 32)  16416       ['tf.concat_67[0][0]']
#  Conv2D)
#
#  Inception_4d_MaxPool_3x3 (MaxP  (None, 14, 14, 512)  0          ['tf.concat_67[0][0]']
#  ooling2D)
#
#  Inception_4d_Conv_1x1 (Conv2D)  (None, 14, 14, 112)  57456      ['tf.concat_67[0][0]']
#
#  Inception_4d_Conv_3x3 (Conv2D)  (None, 14, 14, 288)  373536     ['Inception_4d_Conv_3x3_reduce[0]
#                                                                  [0]']
#
#  Inception_4d_Conv_5x5 (Conv2D)  (None, 14, 14, 64)  51264       ['Inception_4d_Conv_5x5_reduce[0]
#                                                                  [0]']
#
#  Inception_4d_Conv_1x1_pool_por  (None, 14, 14, 64)  32832       ['Inception_4d_MaxPool_3x3[0][0]'
#  j (Conv2D)                                                      ]
#
#  tf.concat_68 (TFOpLambda)      (None, 14, 14, 528)  0           ['Inception_4d_Conv_1x1[0][0]',
#                                                                   'Inception_4d_Conv_3x3[0][0]',
#                                                                   'Inception_4d_Conv_5x5[0][0]',
#                                                                   'Inception_4d_Conv_1x1_pool_porj
#                                                                  [0][0]']
#
#  Inception_4e_Conv_3x3_reduce (  (None, 14, 14, 160)  84640      ['tf.concat_68[0][0]']
#  Conv2D)
#
#  Inception_4e_Conv_5x5_reduce (  (None, 14, 14, 32)  16928       ['tf.concat_68[0][0]']
#  Conv2D)
#
#  Inception_4e_MaxPool_3x3 (MaxP  (None, 14, 14, 528)  0          ['tf.concat_68[0][0]']
#  ooling2D)
#
#  Inception_4e_Conv_1x1 (Conv2D)  (None, 14, 14, 256)  135424     ['tf.concat_68[0][0]']
#
#  Inception_4e_Conv_3x3 (Conv2D)  (None, 14, 14, 320)  461120     ['Inception_4e_Conv_3x3_reduce[0]
#                                                                  [0]']
#
#  Inception_4e_Conv_5x5 (Conv2D)  (None, 14, 14, 128)  102528     ['Inception_4e_Conv_5x5_reduce[0]
#                                                                  [0]']
#
#  Inception_4e_Conv_1x1_pool_por  (None, 14, 14, 128)  67712      ['Inception_4e_MaxPool_3x3[0][0]'
#  j (Conv2D)                                                      ]
#
#  tf.concat_69 (TFOpLambda)      (None, 14, 14, 832)  0           ['Inception_4e_Conv_1x1[0][0]',
#                                                                   'Inception_4e_Conv_3x3[0][0]',
#                                                                   'Inception_4e_Conv_5x5[0][0]',
#                                                                   'Inception_4e_Conv_1x1_pool_porj
#                                                                  [0][0]']
#
#  max_pooling2d_31 (MaxPooling2D  (None, 7, 7, 832)   0           ['tf.concat_69[0][0]']
#  )
#
#  Inception_5a_Conv_3x3_reduce (  (None, 7, 7, 160)   133280      ['max_pooling2d_31[0][0]']
#  Conv2D)
#
#  Inception_5a_Conv_5x5_reduce (  (None, 7, 7, 32)    26656       ['max_pooling2d_31[0][0]']
#  Conv2D)
#
#  Inception_5a_MaxPool_3x3 (MaxP  (None, 7, 7, 832)   0           ['max_pooling2d_31[0][0]']
#  ooling2D)
#
#  Inception_5a_Conv_1x1 (Conv2D)  (None, 7, 7, 256)   213248      ['max_pooling2d_31[0][0]']
#
#  Inception_5a_Conv_3x3 (Conv2D)  (None, 7, 7, 320)   461120      ['Inception_5a_Conv_3x3_reduce[0]
#                                                                  [0]']
#
#  Inception_5a_Conv_5x5 (Conv2D)  (None, 7, 7, 128)   102528      ['Inception_5a_Conv_5x5_reduce[0]
#                                                                  [0]']
#
#  Inception_5a_Conv_1x1_pool_por  (None, 7, 7, 128)   106624      ['Inception_5a_MaxPool_3x3[0][0]'
#  j (Conv2D)                                                      ]
#
#  tf.concat_70 (TFOpLambda)      (None, 7, 7, 832)    0           ['Inception_5a_Conv_1x1[0][0]',
#                                                                   'Inception_5a_Conv_3x3[0][0]',
#                                                                   'Inception_5a_Conv_5x5[0][0]',
#                                                                   'Inception_5a_Conv_1x1_pool_porj
#                                                                  [0][0]']
#
#  Inception_5b_Conv_3x3_reduce (  (None, 7, 7, 192)   159936      ['tf.concat_70[0][0]']
#  Conv2D)
#
#  Inception_5b_Conv_5x5_reduce (  (None, 7, 7, 48)    39984       ['tf.concat_70[0][0]']
#  Conv2D)
#
#  Inception_5b_MaxPool_3x3 (MaxP  (None, 7, 7, 832)   0           ['tf.concat_70[0][0]']
#  ooling2D)
#
#  Inception_5b_Conv_1x1 (Conv2D)  (None, 7, 7, 384)   319872      ['tf.concat_70[0][0]']
#
#  Inception_5b_Conv_3x3 (Conv2D)  (None, 7, 7, 384)   663936      ['Inception_5b_Conv_3x3_reduce[0]
#                                                                  [0]']
#
#  Inception_5b_Conv_5x5 (Conv2D)  (None, 7, 7, 128)   153728      ['Inception_5b_Conv_5x5_reduce[0]
#                                                                  [0]']
#
#  Inception_5b_Conv_1x1_pool_por  (None, 7, 7, 128)   106624      ['Inception_5b_MaxPool_3x3[0][0]'
#  j (Conv2D)                                                      ]
#
#  average_pooling2d_20 (AverageP  (None, 4, 4, 528)   0           ['tf.concat_68[0][0]']
#  ooling2D)
#
#  average_pooling2d_19 (AverageP  (None, 4, 4, 512)   0           ['tf.concat_65[0][0]']
#  ooling2D)
#
#  tf.concat_71 (TFOpLambda)      (None, 7, 7, 1024)   0           ['Inception_5b_Conv_1x1[0][0]',
#                                                                   'Inception_5b_Conv_3x3[0][0]',
#                                                                   'Inception_5b_Conv_5x5[0][0]',
#                                                                   'Inception_5b_Conv_1x1_pool_porj
#                                                                  [0][0]']
#
#  conv2d_39 (Conv2D)             (None, 4, 4, 128)    67712       ['average_pooling2d_20[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 4, 4, 128)    65664       ['average_pooling2d_19[0][0]']
#
#  Olaha_eu (AveragePooling2D)    (None, 1, 1, 1024)   0           ['tf.concat_71[0][0]']
#
#  flatten_15 (Flatten)           (None, 2048)         0           ['conv2d_39[0][0]']
#
#  flatten_14 (Flatten)           (None, 2048)         0           ['conv2d_38[0][0]']
#
#  flatten_16 (Flatten)           (None, 1024)         0           ['Olaha_eu[0][0]']
#
#  dense_15 (Dense)               (None, 1024)         2098176     ['flatten_15[0][0]']
#
#  dense_14 (Dense)               (None, 1024)         2098176     ['flatten_14[0][0]']
#
#  dropout_22 (Dropout)           (None, 1024)         0           ['flatten_16[0][0]']
#
#  dropout_21 (Dropout)           (None, 1024)         0           ['dense_15[0][0]']
#
#  dropout_20 (Dropout)           (None, 1024)         0           ['dense_14[0][0]']
#
#  softmax_2 (Dense)              (None, 10)           10250       ['dropout_22[0][0]']
#
#  softmax_1 (Dense)              (None, 10)           10250       ['dropout_21[0][0]']
#
#  softmax_0 (Dense)              (None, 10)           10250       ['dropout_20[0][0]']
#
# ==================================================================================================
# Total params: 10,327,758
# Trainable params: 10,327,758
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(modelo_view, show_shapes=True)

# %% [markdown]
# # Treinamento

# %%
model = inception_v1(input_shape, num_classes)  
model.compile(optimizer=tf.keras.optimizers.Adam(0.001), 
              loss= ['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'], #keras.losses.sparse_categorical_crossentropy,
              metrics=['accuracy'])

# %%
epocas = 100

# !nvidia-smi
historico = model.fit(X_train, [y_train, y_train, y_train],validation_data=(X_test, [y_test, y_test, y_test]), epochs=epocas, batch_size=256)
# Out:
# Thu May 18 00:34:12 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   76C    P0    33W /  70W |  14543MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# Epoch 1/100
# 12/12 [==============================] - 15s 1s/step - loss: 5.3514 - softmax_2_loss: 0.9153 - softmax_1_loss: 2.2113 - softmax_0_loss: 2.2249 - softmax_2_accuracy: 0.6800 - softmax_1_accuracy: 0.1697 - softmax_0_accuracy: 0.1710 - val_loss: 5.4535 - val_softmax_2_loss: 1.0579 - val_softmax_1_loss: 2.1916 - val_softmax_0_loss: 2.2040 - val_softmax_2_accuracy: 0.5993 - val_softmax_1_accuracy: 0.3137 - val_softmax_0_accuracy: 0.3610
# Epoch 2/100
# 12/12 [==============================] - 14s 1s/step - loss: 5.1323 - softmax_2_loss: 0.7389 - softmax_1_loss: 2.1857 - softmax_0_loss: 2.2077 - softmax_2_accuracy: 0.7560 - softmax_1_accuracy: 0.1767 - softmax_0_accuracy: 0.1863 - val_loss: 5.0787 - val_softmax_2_loss: 0.7002 - val_softmax_1_loss: 2.1774 - val_softmax_0_loss: 2.2011 - val_softmax_2_accuracy: 0.7563 - val_softmax_1_accuracy: 0.3100 - val_softmax_0_accuracy: 0.2823
# Epoch 3/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.8937 - softmax_2_loss: 0.5074 - softmax_1_loss: 2.1816 - softmax_0_loss: 2.2046 - softmax_2_accuracy: 0.8377 - softmax_1_accuracy: 0.1737 - softmax_0_accuracy: 0.1703 - val_loss: 4.9013 - val_softmax_2_loss: 0.5523 - val_softmax_1_loss: 2.1626 - val_softmax_0_loss: 2.1865 - val_softmax_2_accuracy: 0.8147 - val_softmax_1_accuracy: 0.2917 - val_softmax_0_accuracy: 0.2907
# Epoch 4/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.7329 - softmax_2_loss: 0.3765 - softmax_1_loss: 2.1692 - softmax_0_loss: 2.1872 - softmax_2_accuracy: 0.8850 - softmax_1_accuracy: 0.1737 - softmax_0_accuracy: 0.1727 - val_loss: 4.6561 - val_softmax_2_loss: 0.3361 - val_softmax_1_loss: 2.1444 - val_softmax_0_loss: 2.1756 - val_softmax_2_accuracy: 0.8977 - val_softmax_1_accuracy: 0.3157 - val_softmax_0_accuracy: 0.2910
# Epoch 5/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.6254 - softmax_2_loss: 0.2786 - softmax_1_loss: 2.1560 - softmax_0_loss: 2.1908 - softmax_2_accuracy: 0.9163 - softmax_1_accuracy: 0.1737 - softmax_0_accuracy: 0.1750 - val_loss: 4.6069 - val_softmax_2_loss: 0.3131 - val_softmax_1_loss: 2.1293 - val_softmax_0_loss: 2.1644 - val_softmax_2_accuracy: 0.9033 - val_softmax_1_accuracy: 0.3117 - val_softmax_0_accuracy: 0.3003
# Epoch 6/100
# 12/12 [==============================] - 11s 954ms/step - loss: 4.5767 - softmax_2_loss: 0.2591 - softmax_1_loss: 2.1477 - softmax_0_loss: 2.1699 - softmax_2_accuracy: 0.9173 - softmax_1_accuracy: 0.1707 - softmax_0_accuracy: 0.1777 - val_loss: 4.5823 - val_softmax_2_loss: 0.3065 - val_softmax_1_loss: 2.1205 - val_softmax_0_loss: 2.1553 - val_softmax_2_accuracy: 0.9020 - val_softmax_1_accuracy: 0.2963 - val_softmax_0_accuracy: 0.2963
# Epoch 7/100
# 12/12 [==============================] - 11s 963ms/step - loss: 4.4925 - softmax_2_loss: 0.1916 - softmax_1_loss: 2.1402 - softmax_0_loss: 2.1607 - softmax_2_accuracy: 0.9390 - softmax_1_accuracy: 0.1730 - softmax_0_accuracy: 0.1730 - val_loss: 4.4993 - val_softmax_2_loss: 0.2444 - val_softmax_1_loss: 2.1117 - val_softmax_0_loss: 2.1432 - val_softmax_2_accuracy: 0.9240 - val_softmax_1_accuracy: 0.2903 - val_softmax_0_accuracy: 0.3037
# Epoch 8/100
# 12/12 [==============================] - 11s 964ms/step - loss: 4.4600 - softmax_2_loss: 0.1714 - softmax_1_loss: 2.1340 - softmax_0_loss: 2.1546 - softmax_2_accuracy: 0.9450 - softmax_1_accuracy: 0.1767 - softmax_0_accuracy: 0.1723 - val_loss: 4.4453 - val_softmax_2_loss: 0.2091 - val_softmax_1_loss: 2.0907 - val_softmax_0_loss: 2.1454 - val_softmax_2_accuracy: 0.9343 - val_softmax_1_accuracy: 0.2967 - val_softmax_0_accuracy: 0.3027
# Epoch 9/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.4052 - softmax_2_loss: 0.1194 - softmax_1_loss: 2.1226 - softmax_0_loss: 2.1633 - softmax_2_accuracy: 0.9633 - softmax_1_accuracy: 0.1773 - softmax_0_accuracy: 0.1703 - val_loss: 4.3758 - val_softmax_2_loss: 0.1664 - val_softmax_1_loss: 2.0822 - val_softmax_0_loss: 2.1271 - val_softmax_2_accuracy: 0.9473 - val_softmax_1_accuracy: 0.2990 - val_softmax_0_accuracy: 0.3037
# Epoch 10/100
# 12/12 [==============================] - 11s 957ms/step - loss: 4.3711 - softmax_2_loss: 0.0955 - softmax_1_loss: 2.1171 - softmax_0_loss: 2.1584 - softmax_2_accuracy: 0.9713 - softmax_1_accuracy: 0.1757 - softmax_0_accuracy: 0.1777 - val_loss: 4.3794 - val_softmax_2_loss: 0.1930 - val_softmax_1_loss: 2.0695 - val_softmax_0_loss: 2.1169 - val_softmax_2_accuracy: 0.9443 - val_softmax_1_accuracy: 0.2987 - val_softmax_0_accuracy: 0.3207
# Epoch 11/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.3432 - softmax_2_loss: 0.0726 - softmax_1_loss: 2.1205 - softmax_0_loss: 2.1501 - softmax_2_accuracy: 0.9790 - softmax_1_accuracy: 0.1643 - softmax_0_accuracy: 0.1707 - val_loss: 4.3539 - val_softmax_2_loss: 0.1867 - val_softmax_1_loss: 2.0560 - val_softmax_0_loss: 2.1112 - val_softmax_2_accuracy: 0.9507 - val_softmax_1_accuracy: 0.3167 - val_softmax_0_accuracy: 0.3063
# Epoch 12/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.3015 - softmax_2_loss: 0.0573 - softmax_1_loss: 2.1070 - softmax_0_loss: 2.1372 - softmax_2_accuracy: 0.9823 - softmax_1_accuracy: 0.1733 - softmax_0_accuracy: 0.1760 - val_loss: 4.3027 - val_softmax_2_loss: 0.1578 - val_softmax_1_loss: 2.0469 - val_softmax_0_loss: 2.0981 - val_softmax_2_accuracy: 0.9557 - val_softmax_1_accuracy: 0.3067 - val_softmax_0_accuracy: 0.2953
# Epoch 13/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.2880 - softmax_2_loss: 0.0594 - softmax_1_loss: 2.0998 - softmax_0_loss: 2.1289 - softmax_2_accuracy: 0.9820 - softmax_1_accuracy: 0.1713 - softmax_0_accuracy: 0.1930 - val_loss: 4.3211 - val_softmax_2_loss: 0.1901 - val_softmax_1_loss: 2.0407 - val_softmax_0_loss: 2.0903 - val_softmax_2_accuracy: 0.9477 - val_softmax_1_accuracy: 0.3100 - val_softmax_0_accuracy: 0.3407
# Epoch 14/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.2877 - softmax_2_loss: 0.0559 - softmax_1_loss: 2.0977 - softmax_0_loss: 2.1340 - softmax_2_accuracy: 0.9810 - softmax_1_accuracy: 0.1763 - softmax_0_accuracy: 0.1683 - val_loss: 4.2590 - val_softmax_2_loss: 0.1429 - val_softmax_1_loss: 2.0287 - val_softmax_0_loss: 2.0874 - val_softmax_2_accuracy: 0.9550 - val_softmax_1_accuracy: 0.3113 - val_softmax_0_accuracy: 0.3057
# Epoch 15/100
# 12/12 [==============================] - 11s 971ms/step - loss: 4.2419 - softmax_2_loss: 0.0443 - softmax_1_loss: 2.0865 - softmax_0_loss: 2.1111 - softmax_2_accuracy: 0.9857 - softmax_1_accuracy: 0.1747 - softmax_0_accuracy: 0.1777 - val_loss: 4.2852 - val_softmax_2_loss: 0.1908 - val_softmax_1_loss: 2.0184 - val_softmax_0_loss: 2.0760 - val_softmax_2_accuracy: 0.9500 - val_softmax_1_accuracy: 0.3087 - val_softmax_0_accuracy: 0.3067
# Epoch 16/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.2293 - softmax_2_loss: 0.0349 - softmax_1_loss: 2.0746 - softmax_0_loss: 2.1198 - softmax_2_accuracy: 0.9893 - softmax_1_accuracy: 0.1740 - softmax_0_accuracy: 0.1770 - val_loss: 4.2286 - val_softmax_2_loss: 0.1511 - val_softmax_1_loss: 2.0117 - val_softmax_0_loss: 2.0658 - val_softmax_2_accuracy: 0.9553 - val_softmax_1_accuracy: 0.2983 - val_softmax_0_accuracy: 0.3113
# Epoch 17/100
# 12/12 [==============================] - 11s 959ms/step - loss: 4.2272 - softmax_2_loss: 0.0409 - softmax_1_loss: 2.0776 - softmax_0_loss: 2.1087 - softmax_2_accuracy: 0.9863 - softmax_1_accuracy: 0.1757 - softmax_0_accuracy: 0.1763 - val_loss: 4.2176 - val_softmax_2_loss: 0.1611 - val_softmax_1_loss: 1.9992 - val_softmax_0_loss: 2.0573 - val_softmax_2_accuracy: 0.9573 - val_softmax_1_accuracy: 0.3003 - val_softmax_0_accuracy: 0.2937
# Epoch 18/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.2112 - softmax_2_loss: 0.0322 - softmax_1_loss: 2.0859 - softmax_0_loss: 2.0932 - softmax_2_accuracy: 0.9897 - softmax_1_accuracy: 0.1763 - softmax_0_accuracy: 0.1810 - val_loss: 4.1871 - val_softmax_2_loss: 0.1450 - val_softmax_1_loss: 1.9948 - val_softmax_0_loss: 2.0474 - val_softmax_2_accuracy: 0.9627 - val_softmax_1_accuracy: 0.2990 - val_softmax_0_accuracy: 0.2970
# Epoch 19/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.2320 - softmax_2_loss: 0.0329 - softmax_1_loss: 2.0848 - softmax_0_loss: 2.1143 - softmax_2_accuracy: 0.9880 - softmax_1_accuracy: 0.1747 - softmax_0_accuracy: 0.1797 - val_loss: 4.1754 - val_softmax_2_loss: 0.1417 - val_softmax_1_loss: 1.9950 - val_softmax_0_loss: 2.0386 - val_softmax_2_accuracy: 0.9620 - val_softmax_1_accuracy: 0.2970 - val_softmax_0_accuracy: 0.2890
# Epoch 20/100
# 12/12 [==============================] - 11s 954ms/step - loss: 4.2226 - softmax_2_loss: 0.0562 - softmax_1_loss: 2.0665 - softmax_0_loss: 2.0999 - softmax_2_accuracy: 0.9803 - softmax_1_accuracy: 0.1710 - softmax_0_accuracy: 0.1973 - val_loss: 4.2159 - val_softmax_2_loss: 0.1761 - val_softmax_1_loss: 1.9994 - val_softmax_0_loss: 2.0404 - val_softmax_2_accuracy: 0.9523 - val_softmax_1_accuracy: 0.3010 - val_softmax_0_accuracy: 0.3807
# Epoch 21/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.1916 - softmax_2_loss: 0.0410 - softmax_1_loss: 2.0760 - softmax_0_loss: 2.0746 - softmax_2_accuracy: 0.9853 - softmax_1_accuracy: 0.1707 - softmax_0_accuracy: 0.2063 - val_loss: 4.1876 - val_softmax_2_loss: 0.1891 - val_softmax_1_loss: 1.9775 - val_softmax_0_loss: 2.0210 - val_softmax_2_accuracy: 0.9503 - val_softmax_1_accuracy: 0.3000 - val_softmax_0_accuracy: 0.3873
# Epoch 22/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.2056 - softmax_2_loss: 0.0582 - softmax_1_loss: 2.0727 - softmax_0_loss: 2.0747 - softmax_2_accuracy: 0.9807 - softmax_1_accuracy: 0.1773 - softmax_0_accuracy: 0.2013 - val_loss: 4.2043 - val_softmax_2_loss: 0.2323 - val_softmax_1_loss: 1.9712 - val_softmax_0_loss: 2.0008 - val_softmax_2_accuracy: 0.9410 - val_softmax_1_accuracy: 0.3000 - val_softmax_0_accuracy: 0.3917
# Epoch 23/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.1791 - softmax_2_loss: 0.0485 - softmax_1_loss: 2.0676 - softmax_0_loss: 2.0630 - softmax_2_accuracy: 0.9840 - softmax_1_accuracy: 0.1707 - softmax_0_accuracy: 0.1930 - val_loss: 4.0857 - val_softmax_2_loss: 0.1257 - val_softmax_1_loss: 1.9668 - val_softmax_0_loss: 1.9932 - val_softmax_2_accuracy: 0.9617 - val_softmax_1_accuracy: 0.2997 - val_softmax_0_accuracy: 0.3970
# Epoch 24/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.1401 - softmax_2_loss: 0.0362 - softmax_1_loss: 2.0517 - softmax_0_loss: 2.0523 - softmax_2_accuracy: 0.9903 - softmax_1_accuracy: 0.1737 - softmax_0_accuracy: 0.2057 - val_loss: 4.0760 - val_softmax_2_loss: 0.1329 - val_softmax_1_loss: 1.9666 - val_softmax_0_loss: 1.9764 - val_softmax_2_accuracy: 0.9667 - val_softmax_1_accuracy: 0.2943 - val_softmax_0_accuracy: 0.3940
# Epoch 25/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.1486 - softmax_2_loss: 0.0290 - softmax_1_loss: 2.0588 - softmax_0_loss: 2.0608 - softmax_2_accuracy: 0.9913 - softmax_1_accuracy: 0.1733 - softmax_0_accuracy: 0.2007 - val_loss: 4.0831 - val_softmax_2_loss: 0.1595 - val_softmax_1_loss: 1.9560 - val_softmax_0_loss: 1.9677 - val_softmax_2_accuracy: 0.9583 - val_softmax_1_accuracy: 0.2990 - val_softmax_0_accuracy: 0.3893
# Epoch 26/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.1555 - softmax_2_loss: 0.0253 - softmax_1_loss: 2.0635 - softmax_0_loss: 2.0667 - softmax_2_accuracy: 0.9923 - softmax_1_accuracy: 0.1790 - softmax_0_accuracy: 0.1997 - val_loss: 4.0425 - val_softmax_2_loss: 0.1385 - val_softmax_1_loss: 1.9515 - val_softmax_0_loss: 1.9525 - val_softmax_2_accuracy: 0.9627 - val_softmax_1_accuracy: 0.2987 - val_softmax_0_accuracy: 0.3907
# Epoch 27/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.1054 - softmax_2_loss: 0.0205 - softmax_1_loss: 2.0498 - softmax_0_loss: 2.0352 - softmax_2_accuracy: 0.9937 - softmax_1_accuracy: 0.1723 - softmax_0_accuracy: 0.2023 - val_loss: 4.0686 - val_softmax_2_loss: 0.1661 - val_softmax_1_loss: 1.9403 - val_softmax_0_loss: 1.9622 - val_softmax_2_accuracy: 0.9583 - val_softmax_1_accuracy: 0.2997 - val_softmax_0_accuracy: 0.3893
# Epoch 28/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.1018 - softmax_2_loss: 0.0180 - softmax_1_loss: 2.0475 - softmax_0_loss: 2.0363 - softmax_2_accuracy: 0.9950 - softmax_1_accuracy: 0.1807 - softmax_0_accuracy: 0.1963 - val_loss: 4.0003 - val_softmax_2_loss: 0.1237 - val_softmax_1_loss: 1.9382 - val_softmax_0_loss: 1.9384 - val_softmax_2_accuracy: 0.9627 - val_softmax_1_accuracy: 0.2990 - val_softmax_0_accuracy: 0.3963
# Epoch 29/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0898 - softmax_2_loss: 0.0129 - softmax_1_loss: 2.0565 - softmax_0_loss: 2.0205 - softmax_2_accuracy: 0.9957 - softmax_1_accuracy: 0.1713 - softmax_0_accuracy: 0.2063 - val_loss: 4.0012 - val_softmax_2_loss: 0.1355 - val_softmax_1_loss: 1.9260 - val_softmax_0_loss: 1.9397 - val_softmax_2_accuracy: 0.9613 - val_softmax_1_accuracy: 0.3010 - val_softmax_0_accuracy: 0.3960
# Epoch 30/100
# 12/12 [==============================] - 11s 959ms/step - loss: 4.0992 - softmax_2_loss: 0.0109 - softmax_1_loss: 2.0516 - softmax_0_loss: 2.0367 - softmax_2_accuracy: 0.9957 - softmax_1_accuracy: 0.1740 - softmax_0_accuracy: 0.2027 - val_loss: 4.0027 - val_softmax_2_loss: 0.1382 - val_softmax_1_loss: 1.9315 - val_softmax_0_loss: 1.9329 - val_softmax_2_accuracy: 0.9660 - val_softmax_1_accuracy: 0.2963 - val_softmax_0_accuracy: 0.3920
# Epoch 31/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0920 - softmax_2_loss: 0.0118 - softmax_1_loss: 2.0453 - softmax_0_loss: 2.0349 - softmax_2_accuracy: 0.9950 - softmax_1_accuracy: 0.1717 - softmax_0_accuracy: 0.1937 - val_loss: 3.9947 - val_softmax_2_loss: 0.1553 - val_softmax_1_loss: 1.9176 - val_softmax_0_loss: 1.9218 - val_softmax_2_accuracy: 0.9640 - val_softmax_1_accuracy: 0.3007 - val_softmax_0_accuracy: 0.3910
# Epoch 32/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0739 - softmax_2_loss: 0.0195 - softmax_1_loss: 2.0369 - softmax_0_loss: 2.0175 - softmax_2_accuracy: 0.9937 - softmax_1_accuracy: 0.1777 - softmax_0_accuracy: 0.2070 - val_loss: 3.9943 - val_softmax_2_loss: 0.1770 - val_softmax_1_loss: 1.9111 - val_softmax_0_loss: 1.9062 - val_softmax_2_accuracy: 0.9627 - val_softmax_1_accuracy: 0.3003 - val_softmax_0_accuracy: 0.3957
# Epoch 33/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0689 - softmax_2_loss: 0.0144 - softmax_1_loss: 2.0458 - softmax_0_loss: 2.0087 - softmax_2_accuracy: 0.9963 - softmax_1_accuracy: 0.1777 - softmax_0_accuracy: 0.2067 - val_loss: 3.9315 - val_softmax_2_loss: 0.1265 - val_softmax_1_loss: 1.9091 - val_softmax_0_loss: 1.8960 - val_softmax_2_accuracy: 0.9640 - val_softmax_1_accuracy: 0.2997 - val_softmax_0_accuracy: 0.3950
# Epoch 34/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0457 - softmax_2_loss: 0.0067 - softmax_1_loss: 2.0355 - softmax_0_loss: 2.0035 - softmax_2_accuracy: 0.9973 - softmax_1_accuracy: 0.1783 - softmax_0_accuracy: 0.1937 - val_loss: 3.9363 - val_softmax_2_loss: 0.1399 - val_softmax_1_loss: 1.9051 - val_softmax_0_loss: 1.8914 - val_softmax_2_accuracy: 0.9670 - val_softmax_1_accuracy: 0.3047 - val_softmax_0_accuracy: 0.3927
# Epoch 35/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0413 - softmax_2_loss: 0.0039 - softmax_1_loss: 2.0367 - softmax_0_loss: 2.0007 - softmax_2_accuracy: 0.9993 - softmax_1_accuracy: 0.1750 - softmax_0_accuracy: 0.2073 - val_loss: 3.9543 - val_softmax_2_loss: 0.1532 - val_softmax_1_loss: 1.9083 - val_softmax_0_loss: 1.8928 - val_softmax_2_accuracy: 0.9660 - val_softmax_1_accuracy: 0.3037 - val_softmax_0_accuracy: 0.3963
# Epoch 36/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0563 - softmax_2_loss: 0.0080 - softmax_1_loss: 2.0453 - softmax_0_loss: 2.0030 - softmax_2_accuracy: 0.9973 - softmax_1_accuracy: 0.1763 - softmax_0_accuracy: 0.2023 - val_loss: 3.9657 - val_softmax_2_loss: 0.1872 - val_softmax_1_loss: 1.9017 - val_softmax_0_loss: 1.8768 - val_softmax_2_accuracy: 0.9577 - val_softmax_1_accuracy: 0.3053 - val_softmax_0_accuracy: 0.3943
# Epoch 37/100
# 12/12 [==============================] - 11s 961ms/step - loss: 4.0551 - softmax_2_loss: 0.0056 - softmax_1_loss: 2.0458 - softmax_0_loss: 2.0036 - softmax_2_accuracy: 0.9983 - softmax_1_accuracy: 0.1740 - softmax_0_accuracy: 0.2017 - val_loss: 3.9231 - val_softmax_2_loss: 0.1567 - val_softmax_1_loss: 1.8928 - val_softmax_0_loss: 1.8736 - val_softmax_2_accuracy: 0.9683 - val_softmax_1_accuracy: 0.3043 - val_softmax_0_accuracy: 0.3983
# Epoch 38/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0406 - softmax_2_loss: 0.0048 - softmax_1_loss: 2.0494 - softmax_0_loss: 1.9864 - softmax_2_accuracy: 0.9993 - softmax_1_accuracy: 0.1690 - softmax_0_accuracy: 0.2060 - val_loss: 3.9065 - val_softmax_2_loss: 0.1500 - val_softmax_1_loss: 1.8949 - val_softmax_0_loss: 1.8615 - val_softmax_2_accuracy: 0.9663 - val_softmax_1_accuracy: 0.3037 - val_softmax_0_accuracy: 0.3967
# Epoch 39/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0136 - softmax_2_loss: 0.0050 - softmax_1_loss: 2.0266 - softmax_0_loss: 1.9820 - softmax_2_accuracy: 0.9983 - softmax_1_accuracy: 0.1750 - softmax_0_accuracy: 0.2137 - val_loss: 3.9062 - val_softmax_2_loss: 0.1566 - val_softmax_1_loss: 1.8890 - val_softmax_0_loss: 1.8606 - val_softmax_2_accuracy: 0.9670 - val_softmax_1_accuracy: 0.2980 - val_softmax_0_accuracy: 0.3993
# Epoch 40/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0442 - softmax_2_loss: 0.0052 - softmax_1_loss: 2.0384 - softmax_0_loss: 2.0006 - softmax_2_accuracy: 0.9987 - softmax_1_accuracy: 0.1703 - softmax_0_accuracy: 0.2013 - val_loss: 3.9119 - val_softmax_2_loss: 0.1721 - val_softmax_1_loss: 1.8817 - val_softmax_0_loss: 1.8582 - val_softmax_2_accuracy: 0.9657 - val_softmax_1_accuracy: 0.3023 - val_softmax_0_accuracy: 0.4210
# Epoch 41/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0161 - softmax_2_loss: 0.0035 - softmax_1_loss: 2.0225 - softmax_0_loss: 1.9902 - softmax_2_accuracy: 0.9990 - softmax_1_accuracy: 0.1707 - softmax_0_accuracy: 0.2020 - val_loss: 3.9439 - val_softmax_2_loss: 0.1933 - val_softmax_1_loss: 1.8919 - val_softmax_0_loss: 1.8587 - val_softmax_2_accuracy: 0.9660 - val_softmax_1_accuracy: 0.2967 - val_softmax_0_accuracy: 0.3973
# Epoch 42/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0352 - softmax_2_loss: 0.0046 - softmax_1_loss: 2.0375 - softmax_0_loss: 1.9931 - softmax_2_accuracy: 0.9980 - softmax_1_accuracy: 0.1740 - softmax_0_accuracy: 0.2007 - val_loss: 3.8929 - val_softmax_2_loss: 0.1715 - val_softmax_1_loss: 1.8809 - val_softmax_0_loss: 1.8405 - val_softmax_2_accuracy: 0.9700 - val_softmax_1_accuracy: 0.2993 - val_softmax_0_accuracy: 0.4010
# Epoch 43/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0357 - softmax_2_loss: 0.0088 - softmax_1_loss: 2.0451 - softmax_0_loss: 1.9818 - softmax_2_accuracy: 0.9970 - softmax_1_accuracy: 0.1647 - softmax_0_accuracy: 0.1970 - val_loss: 3.8978 - val_softmax_2_loss: 0.1722 - val_softmax_1_loss: 1.8863 - val_softmax_0_loss: 1.8393 - val_softmax_2_accuracy: 0.9637 - val_softmax_1_accuracy: 0.3040 - val_softmax_0_accuracy: 0.3940
# Epoch 44/100
# 12/12 [==============================] - 11s 963ms/step - loss: 4.0521 - softmax_2_loss: 0.0169 - softmax_1_loss: 2.0484 - softmax_0_loss: 1.9867 - softmax_2_accuracy: 0.9940 - softmax_1_accuracy: 0.1740 - softmax_0_accuracy: 0.2057 - val_loss: 3.9441 - val_softmax_2_loss: 0.2238 - val_softmax_1_loss: 1.8803 - val_softmax_0_loss: 1.8400 - val_softmax_2_accuracy: 0.9510 - val_softmax_1_accuracy: 0.2910 - val_softmax_0_accuracy: 0.3893
# Epoch 45/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0224 - softmax_2_loss: 0.0239 - softmax_1_loss: 2.0347 - softmax_0_loss: 1.9638 - softmax_2_accuracy: 0.9923 - softmax_1_accuracy: 0.1710 - softmax_0_accuracy: 0.2137 - val_loss: 3.9538 - val_softmax_2_loss: 0.2540 - val_softmax_1_loss: 1.8741 - val_softmax_0_loss: 1.8258 - val_softmax_2_accuracy: 0.9473 - val_softmax_1_accuracy: 0.3123 - val_softmax_0_accuracy: 0.3947
# Epoch 46/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0266 - softmax_2_loss: 0.0239 - softmax_1_loss: 2.0353 - softmax_0_loss: 1.9673 - softmax_2_accuracy: 0.9903 - softmax_1_accuracy: 0.1697 - softmax_0_accuracy: 0.2150 - val_loss: 3.8721 - val_softmax_2_loss: 0.1812 - val_softmax_1_loss: 1.8669 - val_softmax_0_loss: 1.8240 - val_softmax_2_accuracy: 0.9567 - val_softmax_1_accuracy: 0.2943 - val_softmax_0_accuracy: 0.3990
# Epoch 47/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0495 - softmax_2_loss: 0.0336 - softmax_1_loss: 2.0359 - softmax_0_loss: 1.9800 - softmax_2_accuracy: 0.9907 - softmax_1_accuracy: 0.1747 - softmax_0_accuracy: 0.2003 - val_loss: 3.8956 - val_softmax_2_loss: 0.2122 - val_softmax_1_loss: 1.8681 - val_softmax_0_loss: 1.8152 - val_softmax_2_accuracy: 0.9463 - val_softmax_1_accuracy: 0.3000 - val_softmax_0_accuracy: 0.3993
# Epoch 48/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0466 - softmax_2_loss: 0.0429 - softmax_1_loss: 2.0421 - softmax_0_loss: 1.9616 - softmax_2_accuracy: 0.9877 - softmax_1_accuracy: 0.1667 - softmax_0_accuracy: 0.2057 - val_loss: 3.8499 - val_softmax_2_loss: 0.1801 - val_softmax_1_loss: 1.8582 - val_softmax_0_loss: 1.8115 - val_softmax_2_accuracy: 0.9500 - val_softmax_1_accuracy: 0.2993 - val_softmax_0_accuracy: 0.3983
# Epoch 49/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0231 - softmax_2_loss: 0.0197 - softmax_1_loss: 2.0347 - softmax_0_loss: 1.9687 - softmax_2_accuracy: 0.9930 - softmax_1_accuracy: 0.1743 - softmax_0_accuracy: 0.2120 - val_loss: 3.7757 - val_softmax_2_loss: 0.1098 - val_softmax_1_loss: 1.8607 - val_softmax_0_loss: 1.8052 - val_softmax_2_accuracy: 0.9717 - val_softmax_1_accuracy: 0.2973 - val_softmax_0_accuracy: 0.3977
# Epoch 50/100
# 12/12 [==============================] - 11s 958ms/step - loss: 4.0036 - softmax_2_loss: 0.0088 - softmax_1_loss: 2.0211 - softmax_0_loss: 1.9736 - softmax_2_accuracy: 0.9960 - softmax_1_accuracy: 0.1743 - softmax_0_accuracy: 0.2033 - val_loss: 3.8248 - val_softmax_2_loss: 0.1577 - val_softmax_1_loss: 1.8646 - val_softmax_0_loss: 1.8025 - val_softmax_2_accuracy: 0.9640 - val_softmax_1_accuracy: 0.2970 - val_softmax_0_accuracy: 0.4010
# Epoch 51/100
# 12/12 [==============================] - 11s 962ms/step - loss: 3.9951 - softmax_2_loss: 0.0048 - softmax_1_loss: 2.0307 - softmax_0_loss: 1.9597 - softmax_2_accuracy: 0.9983 - softmax_1_accuracy: 0.1737 - softmax_0_accuracy: 0.2010 - val_loss: 3.8432 - val_softmax_2_loss: 0.1954 - val_softmax_1_loss: 1.8510 - val_softmax_0_loss: 1.7967 - val_softmax_2_accuracy: 0.9623 - val_softmax_1_accuracy: 0.3013 - val_softmax_0_accuracy: 0.4003
# Epoch 52/100
# 12/12 [==============================] - 11s 961ms/step - loss: 4.0301 - softmax_2_loss: 0.0148 - softmax_1_loss: 2.0281 - softmax_0_loss: 1.9871 - softmax_2_accuracy: 0.9953 - softmax_1_accuracy: 0.1663 - softmax_0_accuracy: 0.2007 - val_loss: 3.7877 - val_softmax_2_loss: 0.1447 - val_softmax_1_loss: 1.8428 - val_softmax_0_loss: 1.8002 - val_softmax_2_accuracy: 0.9670 - val_softmax_1_accuracy: 0.3003 - val_softmax_0_accuracy: 0.4003
# Epoch 53/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9912 - softmax_2_loss: 0.0140 - softmax_1_loss: 2.0123 - softmax_0_loss: 1.9649 - softmax_2_accuracy: 0.9950 - softmax_1_accuracy: 0.1767 - softmax_0_accuracy: 0.2063 - val_loss: 3.7940 - val_softmax_2_loss: 0.1476 - val_softmax_1_loss: 1.8541 - val_softmax_0_loss: 1.7923 - val_softmax_2_accuracy: 0.9637 - val_softmax_1_accuracy: 0.3010 - val_softmax_0_accuracy: 0.4007
# Epoch 54/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0161 - softmax_2_loss: 0.0075 - softmax_1_loss: 2.0408 - softmax_0_loss: 1.9678 - softmax_2_accuracy: 0.9980 - softmax_1_accuracy: 0.1627 - softmax_0_accuracy: 0.2033 - val_loss: 3.8000 - val_softmax_2_loss: 0.1597 - val_softmax_1_loss: 1.8448 - val_softmax_0_loss: 1.7955 - val_softmax_2_accuracy: 0.9613 - val_softmax_1_accuracy: 0.2980 - val_softmax_0_accuracy: 0.3990
# Epoch 55/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9923 - softmax_2_loss: 0.0069 - softmax_1_loss: 2.0249 - softmax_0_loss: 1.9605 - softmax_2_accuracy: 0.9973 - softmax_1_accuracy: 0.1783 - softmax_0_accuracy: 0.2020 - val_loss: 3.8223 - val_softmax_2_loss: 0.1923 - val_softmax_1_loss: 1.8442 - val_softmax_0_loss: 1.7857 - val_softmax_2_accuracy: 0.9633 - val_softmax_1_accuracy: 0.2993 - val_softmax_0_accuracy: 0.3967
# Epoch 56/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9851 - softmax_2_loss: 0.0089 - softmax_1_loss: 2.0292 - softmax_0_loss: 1.9471 - softmax_2_accuracy: 0.9980 - softmax_1_accuracy: 0.1823 - softmax_0_accuracy: 0.2070 - val_loss: 3.7585 - val_softmax_2_loss: 0.1473 - val_softmax_1_loss: 1.8363 - val_softmax_0_loss: 1.7749 - val_softmax_2_accuracy: 0.9647 - val_softmax_1_accuracy: 0.3010 - val_softmax_0_accuracy: 0.4010
# Epoch 57/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9887 - softmax_2_loss: 0.0038 - softmax_1_loss: 2.0281 - softmax_0_loss: 1.9568 - softmax_2_accuracy: 0.9993 - softmax_1_accuracy: 0.1790 - softmax_0_accuracy: 0.2073 - val_loss: 3.7939 - val_softmax_2_loss: 0.1668 - val_softmax_1_loss: 1.8565 - val_softmax_0_loss: 1.7707 - val_softmax_2_accuracy: 0.9630 - val_softmax_1_accuracy: 0.2943 - val_softmax_0_accuracy: 0.4013
# Epoch 58/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9992 - softmax_2_loss: 0.0087 - softmax_1_loss: 2.0250 - softmax_0_loss: 1.9654 - softmax_2_accuracy: 0.9967 - softmax_1_accuracy: 0.1760 - softmax_0_accuracy: 0.1997 - val_loss: 3.7545 - val_softmax_2_loss: 0.1551 - val_softmax_1_loss: 1.8267 - val_softmax_0_loss: 1.7727 - val_softmax_2_accuracy: 0.9677 - val_softmax_1_accuracy: 0.2997 - val_softmax_0_accuracy: 0.3970
# Epoch 59/100
# 12/12 [==============================] - 11s 956ms/step - loss: 3.9990 - softmax_2_loss: 0.0069 - softmax_1_loss: 2.0235 - softmax_0_loss: 1.9686 - softmax_2_accuracy: 0.9980 - softmax_1_accuracy: 0.1780 - softmax_0_accuracy: 0.2050 - val_loss: 3.7653 - val_softmax_2_loss: 0.1722 - val_softmax_1_loss: 1.8298 - val_softmax_0_loss: 1.7632 - val_softmax_2_accuracy: 0.9657 - val_softmax_1_accuracy: 0.2997 - val_softmax_0_accuracy: 0.4003
# Epoch 60/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9691 - softmax_2_loss: 0.0061 - softmax_1_loss: 2.0248 - softmax_0_loss: 1.9382 - softmax_2_accuracy: 0.9973 - softmax_1_accuracy: 0.1697 - softmax_0_accuracy: 0.2093 - val_loss: 3.8504 - val_softmax_2_loss: 0.2610 - val_softmax_1_loss: 1.8266 - val_softmax_0_loss: 1.7627 - val_softmax_2_accuracy: 0.9557 - val_softmax_1_accuracy: 0.2997 - val_softmax_0_accuracy: 0.4033
# Epoch 61/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9660 - softmax_2_loss: 0.0044 - softmax_1_loss: 2.0154 - softmax_0_loss: 1.9462 - softmax_2_accuracy: 0.9983 - softmax_1_accuracy: 0.1710 - softmax_0_accuracy: 0.2103 - val_loss: 3.7631 - val_softmax_2_loss: 0.1878 - val_softmax_1_loss: 1.8197 - val_softmax_0_loss: 1.7556 - val_softmax_2_accuracy: 0.9657 - val_softmax_1_accuracy: 0.3010 - val_softmax_0_accuracy: 0.4017
# Epoch 62/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9652 - softmax_2_loss: 0.0057 - softmax_1_loss: 2.0093 - softmax_0_loss: 1.9502 - softmax_2_accuracy: 0.9973 - softmax_1_accuracy: 0.1713 - softmax_0_accuracy: 0.2110 - val_loss: 3.7487 - val_softmax_2_loss: 0.1676 - val_softmax_1_loss: 1.8246 - val_softmax_0_loss: 1.7564 - val_softmax_2_accuracy: 0.9673 - val_softmax_1_accuracy: 0.3017 - val_softmax_0_accuracy: 0.3987
# Epoch 63/100
# 12/12 [==============================] - 11s 954ms/step - loss: 3.9771 - softmax_2_loss: 0.0068 - softmax_1_loss: 2.0182 - softmax_0_loss: 1.9521 - softmax_2_accuracy: 0.9977 - softmax_1_accuracy: 0.1797 - softmax_0_accuracy: 0.2090 - val_loss: 3.7608 - val_softmax_2_loss: 0.1965 - val_softmax_1_loss: 1.8142 - val_softmax_0_loss: 1.7501 - val_softmax_2_accuracy: 0.9683 - val_softmax_1_accuracy: 0.3013 - val_softmax_0_accuracy: 0.3970
# Epoch 64/100
# 12/12 [==============================] - 11s 961ms/step - loss: 3.9824 - softmax_2_loss: 0.0096 - softmax_1_loss: 2.0199 - softmax_0_loss: 1.9529 - softmax_2_accuracy: 0.9970 - softmax_1_accuracy: 0.1727 - softmax_0_accuracy: 0.2033 - val_loss: 3.7512 - val_softmax_2_loss: 0.1499 - val_softmax_1_loss: 1.8457 - val_softmax_0_loss: 1.7555 - val_softmax_2_accuracy: 0.9683 - val_softmax_1_accuracy: 0.2767 - val_softmax_0_accuracy: 0.3990
# Epoch 65/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0241 - softmax_2_loss: 0.0090 - softmax_1_loss: 2.0336 - softmax_0_loss: 1.9815 - softmax_2_accuracy: 0.9967 - softmax_1_accuracy: 0.1753 - softmax_0_accuracy: 0.1920 - val_loss: 3.8526 - val_softmax_2_loss: 0.3016 - val_softmax_1_loss: 1.8095 - val_softmax_0_loss: 1.7416 - val_softmax_2_accuracy: 0.9520 - val_softmax_1_accuracy: 0.3063 - val_softmax_0_accuracy: 0.3990
# Epoch 66/100
# 12/12 [==============================] - 14s 1s/step - loss: 4.0280 - softmax_2_loss: 0.0507 - softmax_1_loss: 2.0126 - softmax_0_loss: 1.9647 - softmax_2_accuracy: 0.9857 - softmax_1_accuracy: 0.1790 - softmax_0_accuracy: 0.2003 - val_loss: 3.6836 - val_softmax_2_loss: 0.1173 - val_softmax_1_loss: 1.8195 - val_softmax_0_loss: 1.7468 - val_softmax_2_accuracy: 0.9663 - val_softmax_1_accuracy: 0.3093 - val_softmax_0_accuracy: 0.3987
# Epoch 67/100
# 12/12 [==============================] - 11s 954ms/step - loss: 4.0103 - softmax_2_loss: 0.0248 - softmax_1_loss: 2.0273 - softmax_0_loss: 1.9582 - softmax_2_accuracy: 0.9923 - softmax_1_accuracy: 0.1673 - softmax_0_accuracy: 0.2113 - val_loss: 3.6867 - val_softmax_2_loss: 0.1394 - val_softmax_1_loss: 1.8094 - val_softmax_0_loss: 1.7380 - val_softmax_2_accuracy: 0.9613 - val_softmax_1_accuracy: 0.3013 - val_softmax_0_accuracy: 0.3987
# Epoch 68/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9631 - softmax_2_loss: 0.0103 - softmax_1_loss: 2.0187 - softmax_0_loss: 1.9341 - softmax_2_accuracy: 0.9970 - softmax_1_accuracy: 0.1753 - softmax_0_accuracy: 0.2077 - val_loss: 3.7147 - val_softmax_2_loss: 0.1705 - val_softmax_1_loss: 1.8095 - val_softmax_0_loss: 1.7347 - val_softmax_2_accuracy: 0.9670 - val_softmax_1_accuracy: 0.3050 - val_softmax_0_accuracy: 0.3980
# Epoch 69/100
# 12/12 [==============================] - 11s 955ms/step - loss: 3.9877 - softmax_2_loss: 0.0076 - softmax_1_loss: 2.0206 - softmax_0_loss: 1.9594 - softmax_2_accuracy: 0.9980 - softmax_1_accuracy: 0.1793 - softmax_0_accuracy: 0.2000 - val_loss: 3.7563 - val_softmax_2_loss: 0.2210 - val_softmax_1_loss: 1.8040 - val_softmax_0_loss: 1.7313 - val_softmax_2_accuracy: 0.9647 - val_softmax_1_accuracy: 0.3013 - val_softmax_0_accuracy: 0.4030
# Epoch 70/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9769 - softmax_2_loss: 0.0101 - softmax_1_loss: 2.0106 - softmax_0_loss: 1.9562 - softmax_2_accuracy: 0.9973 - softmax_1_accuracy: 0.1790 - softmax_0_accuracy: 0.2057 - val_loss: 3.6935 - val_softmax_2_loss: 0.1639 - val_softmax_1_loss: 1.8020 - val_softmax_0_loss: 1.7276 - val_softmax_2_accuracy: 0.9667 - val_softmax_1_accuracy: 0.3020 - val_softmax_0_accuracy: 0.3997
# Epoch 71/100
# 12/12 [==============================] - 11s 962ms/step - loss: 3.9631 - softmax_2_loss: 0.0119 - softmax_1_loss: 2.0088 - softmax_0_loss: 1.9423 - softmax_2_accuracy: 0.9957 - softmax_1_accuracy: 0.1713 - softmax_0_accuracy: 0.2063 - val_loss: 3.6831 - val_softmax_2_loss: 0.1578 - val_softmax_1_loss: 1.8034 - val_softmax_0_loss: 1.7219 - val_softmax_2_accuracy: 0.9640 - val_softmax_1_accuracy: 0.2993 - val_softmax_0_accuracy: 0.4017
# Epoch 72/100
# 12/12 [==============================] - 11s 964ms/step - loss: 3.9821 - softmax_2_loss: 0.0082 - softmax_1_loss: 2.0214 - softmax_0_loss: 1.9524 - softmax_2_accuracy: 0.9977 - softmax_1_accuracy: 0.1717 - softmax_0_accuracy: 0.2070 - val_loss: 3.6731 - val_softmax_2_loss: 0.1559 - val_softmax_1_loss: 1.7973 - val_softmax_0_loss: 1.7198 - val_softmax_2_accuracy: 0.9673 - val_softmax_1_accuracy: 0.3003 - val_softmax_0_accuracy: 0.4027
# Epoch 73/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9602 - softmax_2_loss: 0.0029 - softmax_1_loss: 2.0138 - softmax_0_loss: 1.9435 - softmax_2_accuracy: 0.9990 - softmax_1_accuracy: 0.1800 - softmax_0_accuracy: 0.2087 - val_loss: 3.6493 - val_softmax_2_loss: 0.1353 - val_softmax_1_loss: 1.7958 - val_softmax_0_loss: 1.7181 - val_softmax_2_accuracy: 0.9750 - val_softmax_1_accuracy: 0.3003 - val_softmax_0_accuracy: 0.3970
# Epoch 74/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9747 - softmax_2_loss: 0.0049 - softmax_1_loss: 2.0045 - softmax_0_loss: 1.9653 - softmax_2_accuracy: 0.9980 - softmax_1_accuracy: 0.1803 - softmax_0_accuracy: 0.1960 - val_loss: 3.6833 - val_softmax_2_loss: 0.1738 - val_softmax_1_loss: 1.7958 - val_softmax_0_loss: 1.7137 - val_softmax_2_accuracy: 0.9653 - val_softmax_1_accuracy: 0.3027 - val_softmax_0_accuracy: 0.4027
# Epoch 75/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9712 - softmax_2_loss: 0.0020 - softmax_1_loss: 2.0218 - softmax_0_loss: 1.9474 - softmax_2_accuracy: 0.9993 - softmax_1_accuracy: 0.1747 - softmax_0_accuracy: 0.1943 - val_loss: 3.6258 - val_softmax_2_loss: 0.1266 - val_softmax_1_loss: 1.7872 - val_softmax_0_loss: 1.7120 - val_softmax_2_accuracy: 0.9713 - val_softmax_1_accuracy: 0.3013 - val_softmax_0_accuracy: 0.4003
# Epoch 76/100
# 12/12 [==============================] - 11s 953ms/step - loss: 3.9490 - softmax_2_loss: 0.0014 - softmax_1_loss: 2.0016 - softmax_0_loss: 1.9460 - softmax_2_accuracy: 0.9993 - softmax_1_accuracy: 0.1833 - softmax_0_accuracy: 0.2077 - val_loss: 3.6510 - val_softmax_2_loss: 0.1513 - val_softmax_1_loss: 1.7930 - val_softmax_0_loss: 1.7067 - val_softmax_2_accuracy: 0.9667 - val_softmax_1_accuracy: 0.3017 - val_softmax_0_accuracy: 0.4023
# Epoch 77/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9451 - softmax_2_loss: 0.0017 - softmax_1_loss: 2.0043 - softmax_0_loss: 1.9391 - softmax_2_accuracy: 0.9997 - softmax_1_accuracy: 0.1817 - softmax_0_accuracy: 0.2087 - val_loss: 3.6480 - val_softmax_2_loss: 0.1393 - val_softmax_1_loss: 1.7944 - val_softmax_0_loss: 1.7143 - val_softmax_2_accuracy: 0.9713 - val_softmax_1_accuracy: 0.3010 - val_softmax_0_accuracy: 0.3983
# Epoch 78/100
# 12/12 [==============================] - 11s 954ms/step - loss: 3.9704 - softmax_2_loss: 0.0018 - softmax_1_loss: 2.0398 - softmax_0_loss: 1.9289 - softmax_2_accuracy: 0.9993 - softmax_1_accuracy: 0.1707 - softmax_0_accuracy: 0.2143 - val_loss: 3.6371 - val_softmax_2_loss: 0.1477 - val_softmax_1_loss: 1.7840 - val_softmax_0_loss: 1.7054 - val_softmax_2_accuracy: 0.9713 - val_softmax_1_accuracy: 0.3010 - val_softmax_0_accuracy: 0.4023
# Epoch 79/100
# 12/12 [==============================] - 11s 955ms/step - loss: 3.9468 - softmax_2_loss: 0.0094 - softmax_1_loss: 2.0078 - softmax_0_loss: 1.9296 - softmax_2_accuracy: 0.9983 - softmax_1_accuracy: 0.1780 - softmax_0_accuracy: 0.2097 - val_loss: 3.6233 - val_softmax_2_loss: 0.1297 - val_softmax_1_loss: 1.7930 - val_softmax_0_loss: 1.7006 - val_softmax_2_accuracy: 0.9673 - val_softmax_1_accuracy: 0.3010 - val_softmax_0_accuracy: 0.4023
# Epoch 80/100
# 12/12 [==============================] - 11s 956ms/step - loss: 3.9524 - softmax_2_loss: 0.0039 - softmax_1_loss: 2.0103 - softmax_0_loss: 1.9382 - softmax_2_accuracy: 0.9990 - softmax_1_accuracy: 0.1733 - softmax_0_accuracy: 0.2107 - val_loss: 3.6063 - val_softmax_2_loss: 0.1276 - val_softmax_1_loss: 1.7815 - val_softmax_0_loss: 1.6972 - val_softmax_2_accuracy: 0.9710 - val_softmax_1_accuracy: 0.3017 - val_softmax_0_accuracy: 0.4023
# Epoch 81/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9793 - softmax_2_loss: 0.0026 - softmax_1_loss: 2.0251 - softmax_0_loss: 1.9516 - softmax_2_accuracy: 0.9993 - softmax_1_accuracy: 0.1760 - softmax_0_accuracy: 0.2033 - val_loss: 3.6365 - val_softmax_2_loss: 0.1586 - val_softmax_1_loss: 1.7800 - val_softmax_0_loss: 1.6979 - val_softmax_2_accuracy: 0.9663 - val_softmax_1_accuracy: 0.3017 - val_softmax_0_accuracy: 0.4010
# Epoch 82/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9702 - softmax_2_loss: 0.0019 - softmax_1_loss: 2.0074 - softmax_0_loss: 1.9609 - softmax_2_accuracy: 0.9990 - softmax_1_accuracy: 0.1740 - softmax_0_accuracy: 0.1963 - val_loss: 3.6048 - val_softmax_2_loss: 0.1338 - val_softmax_1_loss: 1.7749 - val_softmax_0_loss: 1.6961 - val_softmax_2_accuracy: 0.9713 - val_softmax_1_accuracy: 0.3017 - val_softmax_0_accuracy: 0.3997
# Epoch 83/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9638 - softmax_2_loss: 0.0012 - softmax_1_loss: 2.0173 - softmax_0_loss: 1.9453 - softmax_2_accuracy: 0.9997 - softmax_1_accuracy: 0.1730 - softmax_0_accuracy: 0.2033 - val_loss: 3.6252 - val_softmax_2_loss: 0.1285 - val_softmax_1_loss: 1.7792 - val_softmax_0_loss: 1.7175 - val_softmax_2_accuracy: 0.9737 - val_softmax_1_accuracy: 0.3013 - val_softmax_0_accuracy: 0.3953
# Epoch 84/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9626 - softmax_2_loss: 0.0013 - softmax_1_loss: 2.0054 - softmax_0_loss: 1.9559 - softmax_2_accuracy: 0.9997 - softmax_1_accuracy: 0.1817 - softmax_0_accuracy: 0.2007 - val_loss: 3.6394 - val_softmax_2_loss: 0.1585 - val_softmax_1_loss: 1.7836 - val_softmax_0_loss: 1.6973 - val_softmax_2_accuracy: 0.9690 - val_softmax_1_accuracy: 0.2993 - val_softmax_0_accuracy: 0.4007
# Epoch 85/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9555 - softmax_2_loss: 0.0020 - softmax_1_loss: 2.0061 - softmax_0_loss: 1.9474 - softmax_2_accuracy: 0.9993 - softmax_1_accuracy: 0.1800 - softmax_0_accuracy: 0.2027 - val_loss: 3.7568 - val_softmax_2_loss: 0.2642 - val_softmax_1_loss: 1.7819 - val_softmax_0_loss: 1.7107 - val_softmax_2_accuracy: 0.9650 - val_softmax_1_accuracy: 0.3013 - val_softmax_0_accuracy: 0.3953
# Epoch 86/100
# 12/12 [==============================] - 11s 957ms/step - loss: 3.9880 - softmax_2_loss: 0.0095 - softmax_1_loss: 2.0246 - softmax_0_loss: 1.9539 - softmax_2_accuracy: 0.9977 - softmax_1_accuracy: 0.1733 - softmax_0_accuracy: 0.1983 - val_loss: 3.6154 - val_softmax_2_loss: 0.1582 - val_softmax_1_loss: 1.7681 - val_softmax_0_loss: 1.6891 - val_softmax_2_accuracy: 0.9670 - val_softmax_1_accuracy: 0.3007 - val_softmax_0_accuracy: 0.4010
# Epoch 87/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9489 - softmax_2_loss: 0.0016 - softmax_1_loss: 2.0157 - softmax_0_loss: 1.9317 - softmax_2_accuracy: 0.9997 - softmax_1_accuracy: 0.1760 - softmax_0_accuracy: 0.2153 - val_loss: 3.5931 - val_softmax_2_loss: 0.1389 - val_softmax_1_loss: 1.7735 - val_softmax_0_loss: 1.6808 - val_softmax_2_accuracy: 0.9713 - val_softmax_1_accuracy: 0.2977 - val_softmax_0_accuracy: 0.4030
# Epoch 88/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9475 - softmax_2_loss: 4.3493e-04 - softmax_1_loss: 1.9980 - softmax_0_loss: 1.9491 - softmax_2_accuracy: 1.0000 - softmax_1_accuracy: 0.1703 - softmax_0_accuracy: 0.2027 - val_loss: 3.6096 - val_softmax_2_loss: 0.1545 - val_softmax_1_loss: 1.7702 - val_softmax_0_loss: 1.6849 - val_softmax_2_accuracy: 0.9750 - val_softmax_1_accuracy: 0.2980 - val_softmax_0_accuracy: 0.4030
# Epoch 89/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9594 - softmax_2_loss: 0.0015 - softmax_1_loss: 2.0141 - softmax_0_loss: 1.9439 - softmax_2_accuracy: 0.9997 - softmax_1_accuracy: 0.1743 - softmax_0_accuracy: 0.2097 - val_loss: 3.6333 - val_softmax_2_loss: 0.1620 - val_softmax_1_loss: 1.7725 - val_softmax_0_loss: 1.6989 - val_softmax_2_accuracy: 0.9713 - val_softmax_1_accuracy: 0.2950 - val_softmax_0_accuracy: 0.3927
# Epoch 90/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9810 - softmax_2_loss: 0.0055 - softmax_1_loss: 2.0139 - softmax_0_loss: 1.9615 - softmax_2_accuracy: 0.9987 - softmax_1_accuracy: 0.1763 - softmax_0_accuracy: 0.2003 - val_loss: 3.6226 - val_softmax_2_loss: 0.1818 - val_softmax_1_loss: 1.7627 - val_softmax_0_loss: 1.6781 - val_softmax_2_accuracy: 0.9657 - val_softmax_1_accuracy: 0.2973 - val_softmax_0_accuracy: 0.3997
# Epoch 91/100
# 12/12 [==============================] - 11s 954ms/step - loss: 3.9400 - softmax_2_loss: 0.0049 - softmax_1_loss: 1.9955 - softmax_0_loss: 1.9395 - softmax_2_accuracy: 0.9970 - softmax_1_accuracy: 0.1737 - softmax_0_accuracy: 0.2053 - val_loss: 3.6089 - val_softmax_2_loss: 0.1658 - val_softmax_1_loss: 1.7681 - val_softmax_0_loss: 1.6750 - val_softmax_2_accuracy: 0.9710 - val_softmax_1_accuracy: 0.2990 - val_softmax_0_accuracy: 0.4023
# Epoch 92/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9533 - softmax_2_loss: 0.0041 - softmax_1_loss: 1.9995 - softmax_0_loss: 1.9497 - softmax_2_accuracy: 0.9980 - softmax_1_accuracy: 0.1837 - softmax_0_accuracy: 0.2047 - val_loss: 3.6238 - val_softmax_2_loss: 0.1907 - val_softmax_1_loss: 1.7559 - val_softmax_0_loss: 1.6772 - val_softmax_2_accuracy: 0.9663 - val_softmax_1_accuracy: 0.3027 - val_softmax_0_accuracy: 0.3980
# Epoch 93/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9391 - softmax_2_loss: 0.0039 - softmax_1_loss: 2.0085 - softmax_0_loss: 1.9267 - softmax_2_accuracy: 0.9990 - softmax_1_accuracy: 0.1710 - softmax_0_accuracy: 0.2027 - val_loss: 3.6481 - val_softmax_2_loss: 0.2144 - val_softmax_1_loss: 1.7589 - val_softmax_0_loss: 1.6748 - val_softmax_2_accuracy: 0.9650 - val_softmax_1_accuracy: 0.3000 - val_softmax_0_accuracy: 0.4003
# Epoch 94/100
# 12/12 [==============================] - 11s 954ms/step - loss: 3.9604 - softmax_2_loss: 0.0161 - softmax_1_loss: 1.9855 - softmax_0_loss: 1.9587 - softmax_2_accuracy: 0.9960 - softmax_1_accuracy: 0.1757 - softmax_0_accuracy: 0.2017 - val_loss: 3.5423 - val_softmax_2_loss: 0.1135 - val_softmax_1_loss: 1.7575 - val_softmax_0_loss: 1.6713 - val_softmax_2_accuracy: 0.9720 - val_softmax_1_accuracy: 0.3007 - val_softmax_0_accuracy: 0.4017
# Epoch 95/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9364 - softmax_2_loss: 0.0065 - softmax_1_loss: 1.9949 - softmax_0_loss: 1.9350 - softmax_2_accuracy: 0.9980 - softmax_1_accuracy: 0.1793 - softmax_0_accuracy: 0.2043 - val_loss: 3.6066 - val_softmax_2_loss: 0.1810 - val_softmax_1_loss: 1.7540 - val_softmax_0_loss: 1.6715 - val_softmax_2_accuracy: 0.9620 - val_softmax_1_accuracy: 0.3043 - val_softmax_0_accuracy: 0.3987
# Epoch 96/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9632 - softmax_2_loss: 0.0098 - softmax_1_loss: 2.0108 - softmax_0_loss: 1.9425 - softmax_2_accuracy: 0.9973 - softmax_1_accuracy: 0.1750 - softmax_0_accuracy: 0.2033 - val_loss: 3.5904 - val_softmax_2_loss: 0.1510 - val_softmax_1_loss: 1.7720 - val_softmax_0_loss: 1.6675 - val_softmax_2_accuracy: 0.9633 - val_softmax_1_accuracy: 0.2953 - val_softmax_0_accuracy: 0.4000
# Epoch 97/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9680 - softmax_2_loss: 0.0039 - softmax_1_loss: 2.0217 - softmax_0_loss: 1.9424 - softmax_2_accuracy: 0.9993 - softmax_1_accuracy: 0.1767 - softmax_0_accuracy: 0.2043 - val_loss: 3.5428 - val_softmax_2_loss: 0.1228 - val_softmax_1_loss: 1.7543 - val_softmax_0_loss: 1.6657 - val_softmax_2_accuracy: 0.9767 - val_softmax_1_accuracy: 0.3007 - val_softmax_0_accuracy: 0.3993
# Epoch 98/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9402 - softmax_2_loss: 0.0029 - softmax_1_loss: 2.0027 - softmax_0_loss: 1.9346 - softmax_2_accuracy: 0.9990 - softmax_1_accuracy: 0.1780 - softmax_0_accuracy: 0.2020 - val_loss: 3.5684 - val_softmax_2_loss: 0.1404 - val_softmax_1_loss: 1.7610 - val_softmax_0_loss: 1.6670 - val_softmax_2_accuracy: 0.9713 - val_softmax_1_accuracy: 0.3020 - val_softmax_0_accuracy: 0.4003
# Epoch 99/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9570 - softmax_2_loss: 0.0051 - softmax_1_loss: 2.0202 - softmax_0_loss: 1.9317 - softmax_2_accuracy: 0.9983 - softmax_1_accuracy: 0.1763 - softmax_0_accuracy: 0.2053 - val_loss: 3.5904 - val_softmax_2_loss: 0.1529 - val_softmax_1_loss: 1.7756 - val_softmax_0_loss: 1.6619 - val_softmax_2_accuracy: 0.9743 - val_softmax_1_accuracy: 0.2927 - val_softmax_0_accuracy: 0.3987
# Epoch 100/100
# 12/12 [==============================] - 14s 1s/step - loss: 3.9856 - softmax_2_loss: 0.0140 - softmax_1_loss: 2.0264 - softmax_0_loss: 1.9452 - softmax_2_accuracy: 0.9957 - softmax_1_accuracy: 0.1757 - softmax_0_accuracy: 0.1997 - val_loss: 3.6232 - val_softmax_2_loss: 0.1867 - val_softmax_1_loss: 1.7717 - val_softmax_0_loss: 1.6648 - val_softmax_2_accuracy: 0.9693 - val_softmax_1_accuracy: 0.2947 - val_softmax_0_accuracy: 0.3987

# %%
model.evaluate(X_test, [y_test, y_test, y_test])
# Out:
# 94/94 [==============================] - 6s 48ms/step - loss: 3.6232 - softmax_2_loss: 0.1867 - softmax_1_loss: 1.7717 - softmax_0_loss: 1.6648 - softmax_2_accuracy: 0.9693 - softmax_1_accuracy: 0.2947 - softmax_0_accuracy: 0.3987
# [3.62316632270813,
#  0.1866927444934845,
#  1.7716542482376099,
#  1.6648188829421997,
#  0.9693333506584167,
#  0.29466667771339417,
#  0.3986666798591614]

# %%
def grafico(historico): 

  plt.subplots(figsize=(25, 5)) 
  # Grafico 1: Loss
  plt.subplot(1,3,1)
  plt.title('Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Cross Entropy')
  plt.grid()
  plt.plot(historico.history['val_loss'], label='Loss de validação geral', color = 'black')
  plt.plot(historico.history['val_softmax_0_loss'], label='Loss de validação Softmax 0 ', color = 'Red')
  plt.plot(historico.history['val_softmax_1_loss'], label='Loss de validação Softmax 1 ', color = 'green')
  plt.plot(historico.history['val_softmax_2_loss'], label='Loss de validação Softmax 2 ', color = 'blue')
  plt.legend()

  # Grafico 2: Acurácia
  plt.subplot(1,3,2)
  plt.title("Accuracy")
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.grid()
  plt.plot(historico.history['val_softmax_0_accuracy'], label='Acuracia de validação Softmax 0 ', color = 'Red')
  plt.plot(historico.history['val_softmax_1_accuracy'], label='Acuracia de validação Softmax 1 ', color = 'green')
  plt.plot(historico.history['val_softmax_2_accuracy'], label='Acuracia de validação Softmax 2 ', color = 'blue')
  plt.legend()

  nome_save = "Treinamento_Inception_V1.jpg"
  plt.savefig(nome_save, dpi=400,  transparent=False)
  plt.show()

grafico(historico)
# Out:
# <ipython-input-47-2f3b9b25f36a>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,1)

# %% [markdown]
# # Teste

# %%
for img in X_test:
  print(model.predict(img))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-55dcb4a73bdf> in <cell line: 1>()
#       1 for img in X_test:
# ----> 2   print(model.predict(img))
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 2169, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 2155, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 2143, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 2111, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/engine/input_spec.py", line 253, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Exception encountered when calling layer 'Inception_V1' (type Functional).
#
#     Input 0 of layer "conv2d_40" is incompatible with the layer: expected min_ndim=4, found ndim=2. Full shape received: (32, 224)
#
#     Call arguments received by layer 'Inception_V1' (type Functional):
#       • inputs=tf.Tensor(shape=(32, 224), dtype=float32)
#       • training=False
#       • mask=None

# %%
model.evaluate(X_test, [y_test, y_test, y_test])

for i in range(len(X_test)):
  model.predict(X_test)
